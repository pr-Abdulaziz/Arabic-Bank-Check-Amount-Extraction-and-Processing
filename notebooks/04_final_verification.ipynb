# %% [markdown]
# # Notebook 4 - Final Verification and Evaluation
#
# ## Quick Note
# - Purpose: compare legal and courtesy outputs and summarize the final metrics.
# - The first cells keep the setup lightweight for tables, plots, and verification outputs.

# %%
# %pip install --upgrade pip
# %pip install torch numpy pandas matplotlib seaborn scikit-learn tqdm

# %%
import random
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from tqdm.auto import tqdm

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

cwd = Path.cwd().resolve()
repo_root = cwd.parent if cwd.name == "notebooks" else cwd

paths = {
    "enhanced_courtesy_values": repo_root / "outputs" / "postprocessing" / "enhanced_courtesy_values.csv",
    "enhanced_legal_values": repo_root / "outputs" / "postprocessing" / "enhanced_legal_values.csv",
    "ground_truth_values": repo_root / "data" / "labels" / "ground_truth_amounts.csv",
    "verification_output": repo_root / "outputs" / "verification" / "verification_results.csv",
    "report_output": repo_root / "outputs" / "verification" / "summary_metrics.csv",
}

for p in [paths["verification_output"].parent]:
    p.mkdir(parents=True, exist_ok=True)

print(f"PyTorch: {torch.__version__}")
print(f"Device: {device}")
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

for k, v in paths.items():
    print(f"{k}: {v} | exists={v.exists()}")

# %%
metrics_config = {
    "target_metrics": [
        "courtesy_digit_accuracy",
        "courtesy_amount_accuracy",
        "legal_character_error_rate",
        "legal_word_error_rate",
        "legal_conversion_accuracy",
        "final_legal_courtesy_matching_accuracy",
        "false_positive_count",
    ],
    "comparison_key": "check_id",
}
pd.DataFrame([metrics_config])

# %%
# Placeholder for final verification implementation in this phase.
print("Final verification setup complete.")
